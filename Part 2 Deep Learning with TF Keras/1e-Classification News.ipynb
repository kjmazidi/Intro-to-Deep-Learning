# %% [markdown]
# <sup>This notebook is adapted from code from *Deep Learning with Python 2nd edition* by Francois Challot.
#
# <sup>See the original code in the books' companion [GitHub](https://github.com/fchollet/deep-learning-with-python-notebooks).  Find the book here: [Amazon Link](https://www.amazon.com/Learning-Python-Second-Fran-C3-A7ois-Chollet-dp-1617296864/dp/1617296864/)

# %% [markdown]
# ## Classifying newswires: A multiclass classification example
#
# Classifying a news article into one of 46 topics.

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ### The Reuters dataset
#
# Again, load with 10K max words in the vocabulary. The data is already divided into train and test sets.

# %% [markdown]
# **Loading the Reuters dataset**

# %%
from tensorflow.keras.datasets import reuters
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(
    num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2113536/2110848 [==============================] - 0s 0us/step
# 2121728/2110848 [==============================] - 0s 0us/step

# %%
len(train_data)
# Out:
# 8982

# %%
len(test_data)
# Out:
# 2246

# %%
print(train_data[10])
# Out:
# [1, 245, 273, 207, 156, 53, 74, 160, 26, 14, 46, 296, 26, 39, 74, 2979, 3554, 14, 46, 4689, 4329, 86, 61, 3499, 4795, 14, 61, 451, 4329, 17, 12]

# %% [markdown]
# ### Decoding newswires back to text
#
# We can use the word index to reconstruct an article.

# %%
word_index = reuters.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_newswire = " ".join([reverse_word_index.get(i - 3, "?") for i in
    train_data[0]])

decoded_newswire
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters_word_index.json
# 557056/550378 [==============================] - 0s 0us/step
# 565248/550378 [==============================] - 0s 0us/step
# '? ? ? said as a result of its december acquisition of space co it expects earnings per share in 1987 of 1 15 to 1 30 dlrs per share up from 70 cts in 1986 the company said pretax net should rise to nine to 10 mln dlrs from six mln dlrs in 1986 and rental operation revenues to 19 to 22 mln dlrs from 12 5 mln dlrs it said cash flow per share this year should be 2 50 to three dlrs reuter 3'

# %%
train_labels[10]
# Out:
# 3

# %% [markdown]
# ### Preparing the data

# %% [markdown]
# ### Encoding the input data
#
# Encoding the same as the IMDB notebook.

# %%
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        for j in sequence:
            results[i, j] = 1.
    return results

# %%
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %% [markdown]
# ### Encoding the labels
#
# The following code will convert the labels from an integer vector to one-hot encoded vectors, where all elements are 0 except for a 1 in the corresponding class position.

# %%
def to_one_hot(labels, dimension=46):
    results = np.zeros((len(labels), dimension))
    for i, label in enumerate(labels):
        results[i, label] = 1.
    return results
y_train = to_one_hot(train_labels)
y_test = to_one_hot(test_labels)

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(train_labels)
y_test = to_categorical(test_labels)

# %% [markdown]
# ### Building your model
#
# This is a harder problem, since we are classifying into one of 46 classes. We will need more layers, and more nodes in the early layers.

# %% [markdown]
# ### Model definition
#
# Two hidden layers with 46 nodes. A softmax output layer with 46 nodes.

# %%
model = keras.Sequential([
    layers.Dense(64, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(46, activation="softmax")
])

# %% [markdown]
# ### Compiling the model
#
# Use categorical crossentropy for multi-class classification.

# %%
model.compile(optimizer="rmsprop",
              loss="categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ### Setting aside a validation set
#
# 10K observations for validation

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]
y_val = y_train[:1000]
partial_y_train = y_train[1000:]

# %% [markdown]
# ### Train the model
#
# 20 epochs

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 16/16 [==============================] - 2s 54ms/step - loss: 2.5828 - accuracy: 0.5392 - val_loss: 1.6958 - val_accuracy: 0.6320
# Epoch 2/20
# 16/16 [==============================] - 1s 41ms/step - loss: 1.3868 - accuracy: 0.7052 - val_loss: 1.2928 - val_accuracy: 0.7200
# Epoch 3/20
# 16/16 [==============================] - 1s 42ms/step - loss: 1.0360 - accuracy: 0.7771 - val_loss: 1.1459 - val_accuracy: 0.7570
# Epoch 4/20
# 16/16 [==============================] - 1s 41ms/step - loss: 0.8250 - accuracy: 0.8269 - val_loss: 1.0379 - val_accuracy: 0.7870
# Epoch 5/20
# 16/16 [==============================] - 1s 42ms/step - loss: 0.6561 - accuracy: 0.8622 - val_loss: 0.9749 - val_accuracy: 0.7930
# Epoch 6/20
# 16/16 [==============================] - 1s 41ms/step - loss: 0.5279 - accuracy: 0.8929 - val_loss: 0.9416 - val_accuracy: 0.8070
# Epoch 7/20
# 16/16 [==============================] - 1s 41ms/step - loss: 0.4277 - accuracy: 0.9126 - val_loss: 0.9357 - val_accuracy: 0.8090
# Epoch 8/20
# 16/16 [==============================] - 1s 41ms/step - loss: 0.3460 - accuracy: 0.9258 - val_loss: 0.9975 - val_accuracy: 0.7790
# Epoch 9/20
# 16/16 [==============================] - 1s 40ms/step - loss: 0.2895 - accuracy: 0.9394 - val_loss: 0.9151 - val_accuracy: 0.8140
# Epoch 10/20
# 16/16 [==============================] - 1s 41ms/step - loss: 0.2396 - accuracy: 0.9459 - val_loss: 0.9258 - val_accuracy: 0.8080
# Epoch 11/20
# 16/16 [==============================] - 1s 41ms/step - loss: 0.2125 - accuracy: 0.9496 - val_loss: 0.9795 - val_accuracy: 0.8000
# Epoch 12/20
# 16/16 [==============================] - 1s 41ms/step - loss: 0.1847 - accuracy: 0.9513 - val_loss: 0.9842 - val_accuracy: 0.7990
# Epoch 13/20
# 16/16 [==============================] - 1s 42ms/step - loss: 0.1676 - accuracy: 0.9549 - val_loss: 0.9752 - val_accuracy: 0.8070
# Epoch 14/20
# 16/16 [==============================] - 1s 42ms/step - loss: 0.1539 - accuracy: 0.9562 - val_loss: 1.0236 - val_accuracy: 0.8020
# Epoch 15/20
# 16/16 [==============================] - 1s 43ms/step - loss: 0.1430 - accuracy: 0.9553 - val_loss: 0.9811 - val_accuracy: 0.8180
# Epoch 16/20
# 16/16 [==============================] - 1s 43ms/step - loss: 0.1334 - accuracy: 0.9565 - val_loss: 1.0306 - val_accuracy: 0.8090
# Epoch 17/20
# 16/16 [==============================] - 1s 42ms/step - loss: 0.1253 - accuracy: 0.9578 - val_loss: 1.0528 - val_accuracy: 0.7970
# Epoch 18/20
# 16/16 [==============================] - 1s 43ms/step - loss: 0.1219 - accuracy: 0.9570 - val_loss: 1.0869 - val_accuracy: 0.8010
# Epoch 19/20
# 16/16 [==============================] - 1s 42ms/step - loss: 0.1157 - accuracy: 0.9577 - val_loss: 1.1094 - val_accuracy: 0.7940
# Epoch 20/20
# 16/16 [==============================] - 1s 41ms/step - loss: 0.1159 - accuracy: 0.9588 - val_loss: 1.0889 - val_accuracy: 0.8010

# %% [markdown]
# ### Plotting the training and validation loss
#
# The model begins to overfit after 9 epochs.

# %%
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ### Plotting the training and validation accuracy

# %%
plt.clf()
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ### Retraining a model from scratch
#
# Use only 9 epochs to avoid overfitting.

# %%
model = keras.Sequential([
  layers.Dense(64, activation="relu"),
  layers.Dense(64, activation="relu"),
  layers.Dense(46, activation="softmax")
])
model.compile(optimizer="rmsprop",
              loss="categorical_crossentropy",
              metrics=["accuracy"])
model.fit(x_train,
          y_train,
          epochs=9,
          batch_size=512)

results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/9
# 18/18 [==============================] - 1s 38ms/step - loss: 2.5666 - accuracy: 0.5335
# Epoch 2/9
# 18/18 [==============================] - 1s 39ms/step - loss: 1.3674 - accuracy: 0.7199
# Epoch 3/9
# 18/18 [==============================] - 1s 38ms/step - loss: 1.0171 - accuracy: 0.7859
# Epoch 4/9
# 18/18 [==============================] - 1s 38ms/step - loss: 0.8062 - accuracy: 0.8348
# Epoch 5/9
# 18/18 [==============================] - 1s 37ms/step - loss: 0.6434 - accuracy: 0.8683
# Epoch 6/9
# 18/18 [==============================] - 1s 37ms/step - loss: 0.5224 - accuracy: 0.8939
# Epoch 7/9
# 18/18 [==============================] - 1s 38ms/step - loss: 0.4232 - accuracy: 0.9093
# Epoch 8/9
# 18/18 [==============================] - 1s 39ms/step - loss: 0.3483 - accuracy: 0.9235
# Epoch 9/9
# 18/18 [==============================] - 1s 38ms/step - loss: 0.2906 - accuracy: 0.9331
# 71/71 [==============================] - 0s 2ms/step - loss: 0.9875 - accuracy: 0.7934

# %%
# accuracy of nearly 80%

results
# Out:
# [0.9375891089439392, 0.7920747995376587]

# %% [markdown]
# Check for the results from a random classifier as a baseline: 19%, so 80% seems good.

# %%
import copy
test_labels_copy = copy.copy(test_labels)
np.random.shuffle(test_labels_copy)
hits_array = np.array(test_labels) == np.array(test_labels_copy)
hits_array.mean()
# Out:
# 0.19412288512911843

# %% [markdown]
# ### Generating predictions on new data
#
# Each prediction is a vector of length 46, which should sum up to 1.

# %%
predictions = model.predict(x_test)

# %%
predictions[0].shape
# Out:
# (46,)

# %%
np.sum(predictions[0])
# Out:
# 0.99999994

# %%
np.argmax(predictions[0])
# Out:
# 3

# %% [markdown]
# ### A different way to handle the labels and the loss
#
# If we leave the labels as integers, we would need to use a different loss function.

# %%
y_train = np.array(train_labels)
y_test = np.array(test_labels)

# %%
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ### The importance of having sufficiently large intermediate layers

# %% [markdown]
# ### A model with an information bottleneck
#
# Validation accuracy drops by about 8%

# %%
model = keras.Sequential([
    layers.Dense(64, activation="relu"),
    layers.Dense(4, activation="relu"),
    layers.Dense(46, activation="softmax")
])
model.compile(optimizer="rmsprop",
              loss="categorical_crossentropy",
              metrics=["accuracy"])
model.fit(partial_x_train,
          partial_y_train,
          epochs=20,
          batch_size=128,
          validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 63/63 [==============================] - 1s 16ms/step - loss: 3.3552 - accuracy: 0.1319 - val_loss: 2.8968 - val_accuracy: 0.2900
# Epoch 2/20
# 63/63 [==============================] - 1s 13ms/step - loss: 2.4303 - accuracy: 0.3438 - val_loss: 2.0917 - val_accuracy: 0.6160
# Epoch 3/20
# 63/63 [==============================] - 1s 13ms/step - loss: 1.6064 - accuracy: 0.6486 - val_loss: 1.5323 - val_accuracy: 0.6400
# Epoch 4/20
# 63/63 [==============================] - 1s 13ms/step - loss: 1.2890 - accuracy: 0.6719 - val_loss: 1.4384 - val_accuracy: 0.6570
# Epoch 5/20
# 63/63 [==============================] - 1s 13ms/step - loss: 1.1727 - accuracy: 0.6918 - val_loss: 1.4119 - val_accuracy: 0.6630
# Epoch 6/20
# 63/63 [==============================] - 1s 14ms/step - loss: 1.0924 - accuracy: 0.7036 - val_loss: 1.4182 - val_accuracy: 0.6690
# Epoch 7/20
# 63/63 [==============================] - 1s 14ms/step - loss: 1.0297 - accuracy: 0.7093 - val_loss: 1.4196 - val_accuracy: 0.6750
# Epoch 8/20
# 63/63 [==============================] - 1s 14ms/step - loss: 0.9781 - accuracy: 0.7181 - val_loss: 1.4336 - val_accuracy: 0.6760
# Epoch 9/20
# 63/63 [==============================] - 1s 13ms/step - loss: 0.9339 - accuracy: 0.7306 - val_loss: 1.4400 - val_accuracy: 0.6830
# Epoch 10/20
# 63/63 [==============================] - 1s 13ms/step - loss: 0.8936 - accuracy: 0.7413 - val_loss: 1.4866 - val_accuracy: 0.6930
# Epoch 11/20
# 63/63 [==============================] - 1s 13ms/step - loss: 0.8595 - accuracy: 0.7547 - val_loss: 1.5260 - val_accuracy: 0.6870
# Epoch 12/20
# 63/63 [==============================] - 1s 14ms/step - loss: 0.8257 - accuracy: 0.7645 - val_loss: 1.5499 - val_accuracy: 0.6790
# Epoch 13/20
# 63/63 [==============================] - 1s 14ms/step - loss: 0.7975 - accuracy: 0.7676 - val_loss: 1.5844 - val_accuracy: 0.6850
# Epoch 14/20
# 63/63 [==============================] - 1s 13ms/step - loss: 0.7699 - accuracy: 0.7717 - val_loss: 1.6490 - val_accuracy: 0.6850
# Epoch 15/20
# 63/63 [==============================] - 1s 14ms/step - loss: 0.7437 - accuracy: 0.7781 - val_loss: 1.6810 - val_accuracy: 0.6820
# Epoch 16/20
# 63/63 [==============================] - 1s 13ms/step - loss: 0.7207 - accuracy: 0.7851 - val_loss: 1.6814 - val_accuracy: 0.6950
# Epoch 17/20
# 63/63 [==============================] - 1s 13ms/step - loss: 0.6932 - accuracy: 0.7977 - val_loss: 1.7770 - val_accuracy: 0.6930
# Epoch 18/20
# 63/63 [==============================] - 1s 13ms/step - loss: 0.6702 - accuracy: 0.8059 - val_loss: 1.8535 - val_accuracy: 0.6890
# Epoch 19/20
# 63/63 [==============================] - 1s 13ms/step - loss: 0.6471 - accuracy: 0.8111 - val_loss: 1.8311 - val_accuracy: 0.6940
# Epoch 20/20
# 63/63 [==============================] - 1s 13ms/step - loss: 0.6298 - accuracy: 0.8121 - val_loss: 1.9711 - val_accuracy: 0.6900

# %% [markdown]
# Things to try:
#
# * using more or fewer layers and units
